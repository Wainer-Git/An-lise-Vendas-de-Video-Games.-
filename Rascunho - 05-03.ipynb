# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np 
# %matplotlib inline

# %%
df = pd.read_csv('vgsales.csv')

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16598 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16598 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Global_Sales    0
# Other_Sales     0
# JP_Sales        0
# EU_Sales        0
# NA_Sales        0
# Publisher       0
# Genre           0
# Year            0
# Platform        0
# Name            0
# Rank            0
# dtype: int64

# %%
yearm = df.Year.median()
df.fillna(yearm, inplace=True)

# %%
sns.heatmap(df.isnull())

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
sns.set_style('darkgrid')
df['Genre'].value_counts().plot(kind='bar', figsize=(9,6))

# %%
df['Publisher'].value_counts().head(10).plot(kind='bar', figsize=(9,6))

# %%
df['Name'].value_counts()
# Out:
# Need for Speed: Most Wanted         12
# Ratatouille                          9
# Madden NFL 07                        9
# LEGO Marvel Super Heroes             9
# FIFA 14                              9
#                                     ..
# Viewpoint                            1
# Taikou Risshiden V                   1
# Desire                               1
# Hole in the Wall: Deluxe Edition     1
# John Madden Football                 1
# Name: Name, Length: 11493, dtype: int64

# %%
df['Platform'].value_counts().head()
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# Name: Platform, dtype: int64

# %%
df.groupby('Genre').mean()
# Out:
#                       Rank         Year  NA_Sales  EU_Sales  JP_Sales  \
# Genre
# Action         7973.879071  2007.909929  0.264726  0.158323  0.048236
# Adventure     11532.787714  2008.130878  0.082271  0.049868  0.040490
# Fighting       7646.511792  2004.630383  0.263667  0.119481  0.103007
# Misc           8561.847039  2007.258480  0.235906  0.124198  0.061967
# Platform       6927.251693  2003.820776  0.504571  0.227573  0.147596
# Puzzle         9627.381443  2005.243433  0.212680  0.087251  0.098471
# Racing         7961.515612  2004.840131  0.287766  0.190865  0.045388
# Role-Playing   8086.174731  2007.055744  0.219946  0.126384  0.236767
# Shooter        7369.367939  2005.918877  0.444733  0.239137  0.029221
# Simulation     8626.085352  2006.567568  0.211430  0.130773  0.073472
# Sports         7425.026428  2005.477865  0.291283  0.160635  0.057702
# Strategy      10071.897210  2005.599106  0.100881  0.066579  0.072628
#
#               Other_Sales  Global_Sales
# Genre
# ...

# %%
g = df['Publisher'].value_counts().head()

# %%
df[df['Publisher']=='Electronic Arts'].groupby('Genre').mean()
# Out:
#                      Rank         Year  NA_Sales  EU_Sales  JP_Sales  \
# Genre
# Action        5899.038251  2007.131868  0.296448  0.240820  0.013607
# Adventure     7743.769231  2004.615385  0.197692  0.126923  0.006154
# Fighting      3841.358974  2004.526316  0.509744  0.224359  0.000769
# Misc          6763.413043  2008.000000  0.324348  0.158696  0.000217
# Platform      6826.562500  2006.125000  0.197500  0.159375  0.003125
# Puzzle        4671.571429  2008.000000  0.380000  0.204286  0.000000
# Racing        4830.880503  2004.628931  0.474969  0.322013  0.007547
# Role-Playing  4531.400000  2009.114286  0.509143  0.325429  0.076000
# Shooter       5062.992806  2007.446043  0.583813  0.403094  0.021079
# Simulation    5953.715517  2006.431034  0.379569  0.308879  0.007586
# Sports        4812.925134  2006.463899  0.481765  0.261979  0.005829
# Strategy      9086.918919  2003.162162  0.238919  0.110811  0.011892
#
#               Other_Sales  Global_Sales
# Genre
# ...

# %%
df[df['Publisher']=='Nintendo'].groupby('Genre').mean()
# Out:
#                      Rank         Year  NA_Sales  EU_Sales  JP_Sales  \
# Genre
# Action        4551.177215  2006.615385  0.803671  0.367342  0.370127
# Adventure     5534.428571  2004.600000  0.506286  0.218857  0.257429
# Fighting      2614.222222  2001.722222  1.505556  0.480000  0.830000
# Misc          5233.090000  2006.250000  0.619800  0.516200  0.552500
# Platform      2195.446429  2001.315315  1.965536  0.760804  0.913929
# Puzzle        4430.135135  2001.810811  0.753243  0.357027  0.501216
# Racing        2218.000000  1999.108108  1.987838  1.074324  0.789730
# Role-Playing  3529.301887  2006.857143  0.996509  0.603019  0.964528
# Shooter       3795.500000  2001.250000  1.976538  0.378846  0.233462
# Simulation    3893.275862  2005.571429  1.024138  0.898276  0.816207
# Sports        3398.818182  2001.254545  1.795818  1.203273  0.652182
# Strategy      5066.750000  2003.580645  0.364375  0.138125  0.326875
#
#               Other_Sales  Global_Sales
# Genre
# ...

# %%
df[(df['Publisher']=='Electronic Arts') & (df['Genre']=='Shooter')].max()
# Out:
# Rank                      16342
# Name                  Viewpoint
# Platform                   XOne
# Year                       2016
# Genre                   Shooter
# Publisher       Electronic Arts
# NA_Sales                   4.46
# EU_Sales                   3.29
# JP_Sales                   0.35
# Other_Sales                1.23
# Global_Sales               7.67
# dtype: object

# %%
df[df['Publisher']=='Electronic Arts'].groupby('Genre').max()
# Out:
#                Rank                                    Name Platform    Year  \
# Genre
# Action        16416  Wing Commander III: Heart of the Tiger     XOne  2015.0
# Adventure     16557                  Xena: Warrior Princess       XB  2011.0
# Fighting      11281                  Warpath: Jurassic Park       XB  2011.0
# Misc          16387                                    Zubo     X360  2011.0
# Platform      13102   Ty the Tasmanian Tiger 2: Bush Rescue     XOne  2016.0
# Puzzle        10926                        We Love Katamari      Wii  2009.0
# Racing        14598                 The Simpsons: Road Rage     XOne  2016.0
# Role-Playing  15332            Untold Legends: Dark Kingdom     XOne  2014.0
# Shooter       16342                               Viewpoint     XOne  2016.0
# Simulation    16180                              Theme Park       XB  2015.0
# Sports        16165                            World Cup 98     XOne  2016.0
# ...

# %%
df[df['Publisher']=='Electronic Arts']['NA_Sales'].max()
# Out:
# 4.46

# %%
df['Platform'].value_counts().head()
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# Name: Platform, dtype: int64

# %%
df[df['Publisher']=='Electronic Arts'].groupby('Platform').max().head()
# Out:
#            Rank                                   Name    Year   Genre  \
# Platform
# 3DS        7804                             The Sims 3  2014.0  Sports
# DS        15986                                   Zubo  2011.0  Sports
# GB         1030  Harry Potter and the Sorcerer's Stone  2001.0  Action
# GBA       14817  Ty the Tasmanian Tiger 2: Bush Rescue  2006.0  Sports
# GC        14598  Ty the Tasmanian Tiger 2: Bush Rescue  2007.0  Sports
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Platform
# 3DS       Electronic Arts      0.36      0.37      0.03         0.07
# DS        Electronic Arts      1.59      1.61      0.21         0.41
# GB        Electronic Arts      0.94      0.62      0.10         0.07
# GBA       Electronic Arts      1.21      0.66      0.08         0.09
# GC        Electronic Arts      0.70      0.48      0.01         0.03
#
#           Global_Sales
# Platform
# 3DS               0.76
# DS                3.69
# ...

# %%
df.groupby('Platform').mean().head()
# Out:
#                   Rank         Year  NA_Sales  EU_Sales  JP_Sales  \
# Platform
# 2600       4403.496241  1982.137931  0.681203  0.041128  0.000000
# 3DO       14372.666667  1994.666667  0.000000  0.000000  0.033333
# 3DS        9160.400786  2013.062000  0.154951  0.114971  0.191257
# DC         8771.423077  1999.942308  0.104423  0.032500  0.164615
# DS         9637.462321  2008.201125  0.180633  0.089991  0.081170
#
#           Other_Sales  Global_Sales
# Platform
# 2600         0.006842      0.729925
# 3DO          0.000000      0.033333
# 3DS          0.024813      0.486169
# DC           0.005192      0.307115
# DS           0.027984      0.380254

# %%
df[df['Platform']=='DS'].mean()
# Out:
# Rank            9637.462321
# Year            2008.201125
# NA_Sales           0.180633
# EU_Sales           0.089991
# JP_Sales           0.081170
# Other_Sales        0.027984
# Global_Sales       0.380254
# dtype: float64

# %%
df[df['Platform']=='DS'].max()
# Out:
# Rank                                   16599
# Name            ¡Shin Chan Flipa en colores!
# Platform                                  DS
# Year                                    2020
# Genre                               Strategy
# NA_Sales                               11.38
# EU_Sales                                  11
# JP_Sales                                 6.5
# Other_Sales                              2.9
# Global_Sales                           30.01
# dtype: object

# %%
df[df['Platform']=='PS2'].max()
# Out:
# Rank                                 16598
# Name            wwe Smackdown vs. Raw 2006
# Platform                               PS2
# Year                                  2011
# Genre                             Strategy
# NA_Sales                              9.43
# EU_Sales                              5.49
# JP_Sales                              3.61
# Other_Sales                          10.57
# Global_Sales                         20.81
# dtype: object

# %%
df[df['JP_Sales']==10.22]
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 4     11.27      8.89     10.22          1.0         31.37

# %%
df['Global_Sales'].max()
# Out:
# 82.74

# %%
df[df['Global_Sales']==82.74]
# Out:
#    Rank        Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo     41.49     29.02
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74
